# %% [markdown]
# ## Satria Nur Saputro
# # Dicoding NLP
# # Dataset [Click me](https://www.kaggle.com/datasets/mrutyunjaybiswal/iitjee-neet-aims-students-questions-data?resource=download)

# %%
# !wget "https://storage.googleapis.com/kaggle-data-sets/957852/1700219/compressed/subjects-questions.csv.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220911%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220911T053132Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
# Out:
# The name is too long, 782 chars total.
# Trying to shorten...
# New name is subjects-questions.csv.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com%2F20220911%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220911T053132Z&X-Goog-Expires=259200&X-Goog-Si.
# --2022-09-11 05:31:48--  https://storage.googleapis.com/kaggle-data-sets/957852/1700219/compressed/subjects-questions.csv.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220911%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220911T053132Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.130.128, 74.125.68.128, 142.250.4.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.130.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10066375 (9.6M) [application/zip]
# Saving to: ‘subjects-questions.csv.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com%2F20220911%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220911T053132Z&X-Goog-Expires=259200&X-Goog-Si’
#
# subjects-questions. 100%[===================>]   9.60M  --.-KB/s    in 0.04s
#
# 2022-09-11 05:31:48 (239 MB/s) - ‘subjects-questions.csv.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com%2F20220911%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220911T053132Z&X-Goog-Expires=259200&X-Goog-Si’ saved [10066375/10066375]

# %% [markdown]
# ubah nama file download menjadi data.zip

# %%
# !unzip "data.zip"
# Out:
# Archive:  data.zip
#   inflating: subjects-questions.csv

# %% [markdown]
# Import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/subjects-questions.csv')
dataset.head()
# Out:
#                                                  eng    Subject
# 0  An anti-forest measure is\nA. Afforestation\nB...    Biology
# 1  Among the following organic acids, the acid pr...  Chemistry
# 2  If the area of two similar triangles are equal...      Maths
# 3  In recent year, there has been a growing\nconc...    Biology
# 4  Which of the following statement\nregarding tr...    Physics

# %% [markdown]
# bar plot perCategory

# %%
kategori_dasatet = dataset.Subject.value_counts()
kategori_dasatet
# Out:
# Physics      38438
# Chemistry    37767
# Maths        33190
# Biology      13124
# Name: Subject, dtype: int64

# %%
bar_dataset = pd.DataFrame(kategori_dasatet,columns=["Subject"])
bar_dataset.plot.bar(y="Subject")

# %% [markdown]
# Convert Category Subject

# %%
category = pd.get_dummies(dataset.Subject)
dataset_baru = pd.concat([dataset, category], axis=1)
dataset_baru = dataset_baru.drop(columns='Subject')
dataset_baru
# Out:
#                                                       eng  Biology  Chemistry  \
# 0       An anti-forest measure is\nA. Afforestation\nB...        1          0
# 1       Among the following organic acids, the acid pr...        0          1
# 2       If the area of two similar triangles are equal...        0          0
# 3       In recent year, there has been a growing\nconc...        1          0
# 4       Which of the following statement\nregarding tr...        0          0
# ...                                                   ...      ...        ...
# 122514  Which of the following group of\ncharacters is...        1          0
# 122515  Light year is the\nA. light emitted by the sun...        0          0
# 122516  Member of Dipnoi are native of\nA. India.\nB. ...        1          0
# 122517  In one average-life,\nA. half the active nucle...        0          0
# 122518  State whether true or false.\nA magnetic field...        0          0
#
#         Maths  Physics
# 0           0        0
# 1           0        0
# 2           1        0
# 3           0        0
# 4           0        1
# ...       ...      ...
# 122514      0        0
# 122515      0        1
# 122516      0        0
# 122517      0        1
# 122518      0        1
#
# [122519 rows x 5 columns]

# %% [markdown]
# # catatan
# Karena data merupakan rumus dan spasial penting maka hanya ubah ke lowercase

# %%
eng = dataset_baru['eng'].str.lower()
label = dataset_baru[['Biology', 'Chemistry', 'Maths','Physics']].values

# %% [markdown]
# Jumlah kata yang ada di dataset dihitung dari per spasi

# %%
jumlah_kata = dataset.eng.str.split()
len(jumlah_kata)
# Out:
# 122519

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(eng, label, test_size=0.2)

print('data training ',len( X_train))
print('target training ',len( y_train))
print('data testing ',len( X_test))
print('target testing ',len( y_test))
# Out:
# (98015,)
# data training  98015
# target training  98015
# data testing  24504
# target testing  24504

# %% [markdown]
# # Tokenization

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

     
tokenizer = Tokenizer(num_words=39433+1, oov_token='x')
tokenizer.fit_on_texts(X_train) 
    
sequences_train = tokenizer.texts_to_sequences(X_train)
sequences_test = tokenizer.texts_to_sequences(X_test)

# %%
word_indexy = tokenizer.word_index
print(len(tokenizer.word_counts))
print(tokenizer.word_counts)
# print(word_indexy)
# print(sequences_test)
# Out:
# 39433
# OrderedDict([('identify', 845), ('the', 191594), ('reaction', 5538), ('that', 10057), ('does', 1984), ('not', 8299), ('take', 752), ('place', 918), ('in', 49815), ('a', 189909), ('blast', 37), ('furnace', 56), ('c', 129785), ('o', 31722), ('3', 60155), ('rightarrow', 5787), ('2', 129471), ('в', 13396), ('s', 24083), ('i', 22142), ('mathbf', 36467), ('cdot', 38271), ('f', 16058), ('e', 17940), ('4', 36500), ('d', 87251), ('boldsymbol', 77391), ('x', 55766), ('h', 36317), ('l', 17444), ('n', 31561), ('correct', 18215), ('option', 451), ('regarding', 325), ('is', 105129), ('are', 28145), ('it', 8913), ('an', 12711), ('strong', 367), ('reducing', 404), ('agent', 616), ('b', 94914), ('angular', 1083), ('molecule', 962), ('used', 2632), ('as', 8799), ('reagent', 183), ('test', 426), ('of', 148832), ('g', 17162), ('radical', 78), ('all', 4756), ('above', 4972), ('charged', 878), ('particle', 2703), ('accelerated', 163), ('through', 3407), ('potential', 2573), ('difference', 1649), ('100', 2956), ('v', 12878), ('passes', 447), ('uniform', 1559), ('electric', 2662), ('and', 65126), ('magnetic', 3062), ('fields', 153), ('so', 1274), ('to', 32370), ('experience', 88), ('no', 2050), ('deflection', 136), ('1', 75623), ('5', 26483), ('times', 12182), ('0', 38289), ('6', 16255), ('m', 34233), ('t', 13344), ('then', 11943), ('specific', 738), ('charge', 2887), ('frac', 43287), ('10', 18572), ('mathrm', 41949), ('kg', 1759), ('9', 6347), ('7', 8999), ('k', 15640), ('helicopter', 23), ('rises', 130), ('vertically', 438), ('with', 15181), ('speed', 2965), ('if', 16288), ('has', 7861), ('length', 3709), ('horizontal', 1355), ('component', 348), ("earth's", 362), ('field', 3755), ('w', 2381), ('induced', 627), ('emf', 772), ('between', 5404), ('tip', 74), ('nose', 19), ('tail', 96), ('50', 2713), ('25', 3450), ('why', 957), ('light', 3206), ('from', 11405), ('clear', 61), ('blue', 601), ('portion', 122), ('sky', 79), ('show', 1160), ('rise', 299), ('fall', 306), ('intensity', 691), ('when', 6269), ('viewed', 47), ('polaroid', 29), ('which', 17205), ('rotated', 174), ('explain', 1001), ('by', 14563), ('drawing', 60), ('necessary', 151), ('diagram', 873), ('describe', 301), ('primary', 579), ('structure', 720), ('monocot', 63), ('root', 580), ('find', 9814), ('value', 5571), ('using', 1098), ('cross', 699), ('multiplication', 61), ('method', 731), ('15', 3104), ('causes', 265), ('pimples', 3), ('both', 9882), ('boys', 114), ('girls', 101), ('at', 17948), ('puberty', 45), ('increased', 710), ('activity', 263), ('sweat', 19), ('sebaceous', 8), ('gland', 178), ('decreased', 172), ('inactivity', 2), ('glan', 1), ('viral', 3), ('infection', 16), ('urine', 106), ('stored', 269), ('kidney', 165), ('urinary', 37), ('bladder', 53), ('ureter', 29), ('urethra', 32), ('moves', 886), ('such', 1706), ('its', 6914), ('average', 839), ('velocity', 4408), ('8', 10071), ('ms', 571), ('assertion', 14920), ('motion', 1559), ('projectile', 93), ('remains', 773), ('constant', 3768), ('reason', 15179), ('force', 3970), ('on', 12128), ('gravitational', 535), ('acts', 421), ('only', 3195), ('downward', 142), ('direction', 2227), ('explanation', 4951), ('for', 15821), ('but', 7122), ('incorrect', 4179), ('solve', 912), ('left', 22338), ('right', 22716), ('div', 152), ('widely', 43), ('metallurgic', 1), ('process', 1818), ('because', 1264), ('this', 5536), ('question', 3225), ('multiple', 2726), ('options', 2657), ('many', 1364), ('metals', 800), ('react', 280), ('elevated', 10), ('temperature', 3977), ('forming', 128), ('hydrides', 95), ('there', 1486), ('risk', 13), ('explosion', 73), ('present', 1325), ('air', 1960), ('power', 1068), ('increase', 1614), ('increases', 1767), ('ethylene', 191), ('dibromide', 7), ('r', 19808), ('dibromopropane', 4), ('forms', 634), ('series', 1193), ('ideal', 660), ('solution', 4326), ('over', 716), ('whole', 203), ('range', 461), ('composition', 194), ('85', 291), ('circ', 8951), ('vapour', 595), ('pressure', 3222), ('these', 5617), ('pure', ...

# %% [markdown]
# # Padding

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_train = pad_sequences(sequences_train, maxlen=1054,  padding='post') 
padded_test = pad_sequences(sequences_test,  maxlen=1054, padding='post')
print(padded_train.shape)
print(padded_test.shape)
# Out:
# (98015, 1054)
# (24504, 1054)

# %% [markdown]
# Model

# %%
from tensorflow import keras

from keras.models import Sequential
from keras.layers import Dense, Embedding, Bidirectional, TimeDistributed, LSTM, Dropout
model = Sequential()

model = keras.Sequential()

model.add(Embedding(input_dim=39433 + 1,output_dim=16))
model.add(Bidirectional(LSTM(64)))
model.add(Dropout(0.2))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='softmax'))

# %% [markdown]
# # Optimizer and loss

# %%
optimizers = keras.optimizers.Adam(1e-3)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers,
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_62"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_32 (Embedding)    (None, None, 16)          630944
#
#  bidirectional_28 (Bidirecti  (None, 128)              41472
#  onal)
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_66 (Dense)            (None, 8)                 1032
#
#  dense_67 (Dense)            (None, 4)                 36
#
# =================================================================
# Total params: 673,484
# Trainable params: 673,484
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # callback

# %%
class callback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy') > 0.92):
      self.model.stop_training = True

callbacks = callback()
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss',mode="max", patience=3)

# %% [markdown]
# # Training data

# %%
num_epochs = 200
history = model.fit(padded_train, y_train, epochs=num_epochs, callbacks=[callbacks,early_stopping],
                    validation_data = (padded_test, y_test), batch_size=4,verbose=2)
# Out:
# Epoch 1/200
# 24504/24504 - 1581s - loss: 0.2926 - accuracy: 0.8937 - val_loss: 0.1954 - val_accuracy: 0.9322 - 1581s/epoch - 65ms/step
# Epoch 2/200
# 24504/24504 - 1560s - loss: 0.1609 - accuracy: 0.9447 - val_loss: 0.1842 - val_accuracy: 0.9372 - 1560s/epoch - 64ms/step

# %% [markdown]
# # Plot akurasi dan loss

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
